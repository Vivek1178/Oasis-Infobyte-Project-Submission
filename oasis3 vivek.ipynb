# %%
import pandas as pd
import numpy as np
import seaborn as sns
import string
import re
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VIVEK\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
spam=pd.read_csv(r'C:\Users\VIVEK\Downloads\oasis\task4\spam.csv',encoding='latin8')

# %%
spam
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
spam=spam.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1)

# %%
spam
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
spam=spam.rename(columns={'v1':'Label','v2':'sms'})

# %%
spam
# Out:
#      Label                                                sms
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
spam['sms'].isnull().sum()
# Out:
# 0

# %%
spam.isnull().sum()
# Out:
# Label    0
# sms      0
# dtype: int64

# %%
# performing nlp
punctuations=re.compile(r'[^/.\w\s]')
spam['sms']=spam['sms'].replace(punctuations,'')

# %%
spam
# Out:
#      Label                                                sms
# 0      ham  Go until jurong point crazy.. Available only i...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I dont think he goes to usf he lives aroun...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will Ì_ b going to esplanade fr home
# 5569   ham  Pity  was in mood for that. So...any other sug...
# 5570   ham  The guy did some bitching but I acted like id ...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
type(spam['sms'])
# Out:
# pandas.core.series.Series

# %%
def expand(phrase):
  phrase = re.sub(r"won\'t", "will not",phrase)
  phrase = re.sub(r"can\'t", "can not",phrase)
  phrase = re.sub(r"n\'t", " not",phrase)
  phrase = re.sub(r"\'re", " are",phrase)
  phrase = re.sub(r"\'s", " is",phrase)
  phrase = re.sub(r"\'d", " would",phrase)
  phrase = re.sub(r"\'ll", " will",phrase)
  phrase = re.sub(r"\'t", " not",phrase)
  phrase = re.sub(r"\'ve", " have",phrase)
  phrase = re.sub(r"\'m", " am",phrase)
  return phrase
spam['sms']=spam['sms'].map(expand)

# %%
spam['sms']=spam['sms'].map(str.lower)

# %%
from nltk.corpus import stopwords

# %%
stop_words=set(stopwords.words('english'))
stop_words.add('subject')
stop_words.add('http')
def remove_stopwords(text):
  return " ".join(word for word in str(text).split() if word not in stop_words)

# %%
spam['sms']=spam['sms'].map(remove_stopwords)

# %%
spam['sms']
# Out:
# 0       go jurong point crazy.. available bugis n grea...
# 1                           ok lar... joking wif u oni...
# 2       free entry 2 wkly comp win fa cup final tkts 2...
# 3               u dun say early hor... u c already say...
# 4             nah dont think goes usf lives around though
#                               ...
# 5567    2nd time tried 2 contact u. u å750 pound prize...
# 5568                         ì_ b going esplanade fr home
# 5569                 pity mood that. so...any suggestions
# 5570    guy bitching acted like id interested buying s...
# 5571                                      rofl. true name
# Name: sms, Length: 5572, dtype: object

# %%
from nltk.stem import PorterStemmer

# %%
stemmer=PorterStemmer()
def stemmer_words(text):
  return " ".join(stemmer.stem(word) for word in text.split() )

# %%
spam['sms']=spam['sms'].map(stemmer_words)

# %%
spam
# Out:
#      Label                                                sms
# 0      ham  go jurong point crazy.. avail bugi n great wor...
# 1      ham                        ok lar... joke wif u oni...
# 2     spam  free entri 2 wkli comp win fa cup final tkt 21...
# 3      ham          u dun say earli hor... u c alreadi say...
# 4      ham          nah dont think goe usf live around though
# ...    ...                                                ...
# 5567  spam  2nd time tri 2 contact u. u å750 pound prize. ...
# 5568   ham                           ì_ b go esplanad fr home
# 5569   ham                   piti mood that. so...ani suggest
# 5570   ham  guy bitch act like id interest buy someth els ...
# 5571   ham                                    rofl. true name
#
# [5572 rows x 2 columns]

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\VIVEK\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\VIVEK\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()
def word_lematizer(text):
  return ' '.join(lemmatizer.lemmatize(word) for word in text.split())

# %%
spam['sms']=spam['sms'].map(word_lematizer)

# %%
spam['sms'].values
# Out:
# array(['go jurong point crazy.. avail bugi n great world la e buffet... cine got amor wat...',
#        'ok lar... joke wif u oni...',
#        'free entri 2 wkli comp win fa cup final tkt 21st may 2005. text fa 87121 receiv entri questionstd txt ratetc appli 08452810075over18',
#        ..., 'piti mood that. so...ani suggest',
#        'guy bitch act like id interest buy someth el next week gave u free',
#        'rofl. true name'], dtype=object)

# %%
[x for x in spam['sms']]
# Out:
# ['go jurong point crazy.. avail bugi n great world la e buffet... cine got amor wat...',
#  'ok lar... joke wif u oni...',
#  'free entri 2 wkli comp win fa cup final tkt 21st may 2005. text fa 87121 receiv entri questionstd txt ratetc appli 08452810075over18',
#  'u dun say earli hor... u c alreadi say...',
#  'nah dont think goe usf live around though',
#  'freemsg hey darl 3 week word back id like fun still tb ok xxx std chg send å1.50 rcv',
#  'even brother like speak me. treat like aid patent.',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun callers. press 9 copi friend callertun',
#  'winner valu network custom select receivea å900 prize reward claim call 09061701461. claim code kl341. valid 12 hour only.',
#  'mobil 11 month u r entitl updat latest colour mobil camera free call mobil updat co free 08002986030',
#  'im gonna home soon dont want talk stuff anymor tonight k ive cri enough today.',
#  'six chanc win cash 100 20000 pound txt csh11 send 87575. cost 150p/day 6day 16 tsandc appli repli hl 4 info',
#  'urgent 1 week free membership å100000 prize jackpot txt word claim 81010 tc www.dbuk.net lccltd pobox 4403ldnw1a7rw18',
#  'ive search right word thank breather. promis wont take help grant fulfil promise. wonder bless times.',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt messag click http//wap. xxxmobilemovieclub.comnqjkgighjjgcbl',
#  'oh k...im watch',
#  'eh u rememb 2 spell name... ye did. v naughti make v wet.',
#  'fine thatåõ way u feel. thatåõ way gota b',
#  'england v macedonia dont miss goals/team news. txt ur nation team 87077 eg england 87077 trywal scotland 4txt/ìỳ1.20 poboxox36504w45wq 16',
#  'serious spell name',
#  'iûṫm go tri 2 month ha ha joke',
#  'ì_ pay first lar... da stock comin...',
#  'aft finish lunch go str lor. ard 3 smth lor. u finish ur lunch alreadi',
#  'ffffffffff. alright way meet sooner',
#  'forc eat slice. im realli hungri tho. sucks. mark get worried. know im sick turn pizza. lol',
#  'lol alway convincing.',
#  'catch bu fri egg make tea eat mom left dinner feel love',
#  'im back amp pack car ill let know there room',
#  'ahhh. work. vagu rememb feel like lol',
#  'wait that still clear sure sarcast that x doesnt want live u',
#  'yeah got 2 v apologetic. n fallen actin like spoilt child got caught that. till 2 wont go badli cheers.',
#  'k tell anyth you.',
#  'fear faint housework quick cuppa',
#  'thank subscript rington uk mobil charg å5/month plea confirm repli ye no. repli charg',
#  'yup... ok go home look time msg ì_ again... xuhui go learn 2nd may lesson 8am',
#  'oop ill let know roommat done',
#  'see letter b car',
#  'anyth lor... u decide...',
#  'hello how saturday go text see youd decid anyth tomo. im tri invit anyth',
#  'pl go ahead watts. want sure. great weekend. abiola',
#  'forget tell want need crave ... ... love sweet arabian steed ... mmmmmm ... yummi',
#  '07732584351 rodger burn msg tri call repli sm free nokia mobil free camcorder. plea call 08000930705 deliveri tomorrow',
#  'see',
#  'great hope like man well endowed. ltgt inches...',
#  'calls..messages..miss call',
#  'didnt get hep b immunis nigeria.',
#  'fair enough anyth go',
#  'yeah hope tyler cant could mayb ask around bit',
#  'u dont know stubborn am. didnt even want go hospital. kept tell mark im weak sucker. hospit weak suckers.',
#  'think me. first time saw class.',
#  'gram usual run like ltgt half eighth smarter though get almost whole second gram ltgt',
#  'k fyi x ride earli tomorrow morn he crash place tonight',
#  'wow. never realiz embarass accomodations. thought like sinc best could alway seem happi cave. im sorri didnt dont give. im sorri offered. im sorri room embarassing.',
#  'sms. ac sptv new jersey devil detroit red wing play ice hockey. correct incorrect end repli end sptv',
#  'know mallika sherawat yesterday find lturlgt',
#  'congrat 1 year special cinema pas 2 yours. call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45we. 150pm. dont miss',
#  'sorri ill call later meeting.',
#  'tell reach',
#  'yes..gauti sehwag odi series.',
#  'gonna pick 1 burger way home. cant even move. pain kill me.',
#  'ha ha ha good joke. girl situat seekers.',
#  'part check iq',
#  'sorri roommat took forev ok come',
#  'ok lar doubl check wif da hair dresser alreadi said wun cut v short. said cut look nice.',
#  'valu custom plea advis follow recent review mob no. award å1500 bonu prize call 09066364589',
#  'today song dedic day.. song u dedic send ur valuabl frnd first rpli me...',
#  'urgent ur award complimentari trip eurodisinc trav acoentry41 å1000. claim txt di 87121 186å1.50morefrmmob. shracomorsglsuplt10 ls1 3aj',
#  'hear new divorc barbi come ken stuff',
#  'plane give month end.',
#  'wah lucki man... save money... hee...',
#  'finish class you.',
#  'hi babe im home wanna someth xx',
#  'k..kwhere youhow perform',
#  'u call now...',
#  'wait machan. call free.',
#  'that cool. gentleman treat digniti respect.',
#  'like peopl much shi pa.',
#  'oper ltgt',
#  'here. still look job. much ta earn there.',
#  'sorri ill call later',
#  'k. call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop.',
#  'call later dont network. urgnt sm me.',
#  'real u get yo need 2 ticket one jacket im done. alreadi use multis.',
#  'ye start send request make pain came back im back bed. doubl coin factori too. gotta cash nitros.',
#  'im realli still tonight babe',
#  'ela kano.il download come wen ur free..',
#  'yeah donûṫt stand close tho youûṫll catch someth',
#  'sorri pain. ok meet anoth night spent late afternoon casualti mean havent done stuff42moro includ time sheet that. sorry.',
#  'smile pleasur smile pain smile troubl pour like rain smile sum1 hurt u smile becoz someon still love see u smile',
#  'plea call custom servic repres 0800 169 6031 10am9pm guarante å1000 cash å5000 prize',
#  'havent plan buy later. check alreadi lido got 530 show e afternoon. u finish work alreadi',
#  'free rington wait collected. simpli text password mix 85069 verify. get usher britney. fml',
#  'watch telugu movie..wat abt u',
#  'see. finish load loan pay',
#  'hi. wk ok hol ye bit run. forgot hairdress appoint four need get home n shower beforehand. caus prob u ham',
#  'plea dont text anymore. noth el say.',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'im still look car buy. gone 4the drive test yet.',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun callers. press 9 copi friend callertun',
#  'wow. your right didnt mean that. guess gave boston men chang search locat nyc someth changed. cuz signin page still say boston.',
#  'umma life vava umma love lot dear',
#  'thank lot wish birthday. thank make birthday truli memorable.',
#  'aight ill hit get cash',
#  'would ip address test consid comput isnt minecraft server',
#  'know grumpi old people. mom like better lying. alway one play jokes...',
#  'dont worry. guess he busy.',
#  'plural noun research',
#  'go dinner.msg after.',
#  'im ok wif co like 2 tri new things. scare u dun like mah. co u said loud.',
#  'gent tri contact you. last weekend draw show å1000 prize guaranteed. call 09064012160. claim code k52. valid 12hr only. 150ppm',
#  'wa ur openin sentenc formal... anyway im fine juz tt im eatin much n puttin weight...haha... anythin special happen',
#  'enter cabin pa said happi bday bos . felt special. askd 4 lunch. lunch invit apartment. went there.',
#  'winner u special select 2 receiv å1000 4 holiday flight inc speak live oper 2 claim 0871277810910p/min 18',
#  'goodo ye must speak friday eggpotato ratio tortilla need',
#  'hmm...mi uncl inform he pay school directly. pl buy food.',
#  'privat 2004 account statement 07742676969 show 786 unredeem bonu points. claim call 08719180248 identifi code 45239 expir',
#  'urgent mobil no. award å2000 bonu caller prize 5/9/03 final tri contact u call landlin 09064019788 box42wr29c 150ppm',
#  'new address applespairsal malarki',
#  'today voda number end 7548 select receiv 350 award. match plea call 08712300220 quot claim code 4041 standard rate app',
#  'go sao mu today. done 12',
#  'ìï predict wat time ì_ll finish buy',
#  'good stuff do.',
#  'knowyetund hasnt sent money yet. sent text bother sending. dont involv anything. shouldnt impos anyth first place apologise.',
#  'room.',
#  'hey girl. r u hope u r well del r bak long time c give call sum time lucyxx',
#  'k..khow much cost',
#  'im home.',
#  'dear call tmorrow.pl accomodate.',
#  'first answer question.',
#  'sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr 82277. å1.50 sptyron',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network bt txting gravel 69888 nt. ec2a. 31p.msg150p',
#  'haf msn. yijuehotmail.com',
#  'there. call meet',
#  'no. check room befor activ',
#  'youll rcv msg chat svc. free hardcor servic text go 69988 u get noth u must age verifi yr network tri',
#  'got c... lazi type... forgot ì_ lect... saw pouch like v nice...',
#  'k text your way',
#  'sir wait mail.',
#  'swt thought nver get tire littl thing 4 lovabl persons.. coz..somtim littl thing occupi biggest part hearts.. gud ni8',
#  'know are. pl open back',
#  'ye see ya dot',
#  'what staff name take class u',
#  'freemsg havent repli text im randi sexi femal live local. luv hear u. netcollex ltd 08700621170150p per msg repli stop end',
#  'ummma.wil call check in.our life begin qatar pl pray hard.',
#  'k..i delet contact',
#  'sindu got job birla soft ..',
#  'wine flow im nevering..',
#  'yup thk cine better co need 2 go 2 plaza mah.',
#  'ok... ur typic reply...',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun callers. press 9 copi friend callertun',
#  'everywher dirt floor window even shirt. sometim open mouth come flow out. dream world without half chore too. time joy lot tv show i.ll see. guess like thing must exist like rain hail mist time done becom one.',
#  'aaooooright work',
#  'im leav hous now...',
#  'hello love. get interview today happi good boy think mear miss',
#  'custom servic annoncement. new year deliveri wait you. plea call 07046744435 arrang deliveri',
#  'winner u special select 2 receiv å1000 cash 4 holiday flight inc speak live oper 2 claim 0871277810810',
#  'keep safe need miss alreadi envi everyon see real life',
#  'new car hous parents.i new job hand',
#  'im love you. im excit day spend you. make happy.',
#  'pl stop bootydeli 32/f invit friend. repli yes434 no434 see www.sms.ac/u/bootydeli stop send stop frnd 62468',
#  'bangbab ur order way. u receiv servic msg 2 download ur content. u goto wap. bangb. tv ur mobil internet/servic menu',
#  'place ur point e cultur modul already.',
#  'urgent tri contact you. last weekend draw show å900 prize guaranteed. call 09061701939. claim code s89. valid 12hr',
#  'hi frnd best way avoid missunderstd wit belov one',
#  'great escape. fanci bridg need lager. see tomo',
#  'ye complet formclark also utter waste.',
#  'sir need axi bank account bank address.',
#  'hmmm.. thk sure got time hop ard... ya go 4 free abt... muz call u discus liao...',
#  'time come later',
#  'bloodi hell cant believ forgot surnam mr . ill give u clue spanish begin m...',
#  'well im gonna finish bath now. good...fin night.',
#  'let know youv got money carlo make call',
#  'u still go mall',
#  'turn friend stay whole show wont back til ltgt feel free go ahead smoke ltgt worth',
#  'text her. doesnt repli let know log',
#  'hi spoke maneesha v. wed like know satisfi experience. repli toll free ye no.',
#  'lift hope offer money. need. especi end month approach hurt studying. anyway gr8 weekend',
#  'lol no. u trust me.',
#  'ok. gentleman treat digniti respect.',
#  'guy close',
#  'go noth great.by',
#  'hello handsom find job lazi work toward get back net mummi where boytoy miss',
#  'haha awesom minut',
#  'plea call custom servic repres freephon 0808 145 4742 9am11pm guarante å1000 cash å5000 prize',
#  'got xma radio times. get',
#  'ju reach home. go bath first. si use net tell u finish k...',
#  'uniqu enough find 30th august. www.areyouunique.co.uk',
#  'im sorry. ive join leagu peopl dont keep touch. mean great deal me. friend time even great person cost. great week.',
#  'hi final complet cours',
#  'stop itself. howev suggest stay someon abl give or everi stool.',
#  'hope youv settl new school year. wishin gr8 day',
#  'gud mrng dear hav nice day',
#  'u got person stori',
#  'hamster dead hey tmr meet 1pm orchard mrt',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back u can. xxx',
#  'found enc ltgt',
#  'sent ltgt buck',
#  'hello darlin ive finish colleg txt u finish u love kate xxx',
#  'account refil success inr ltdecimalgt . keralacircl prepaid account balanc r ltdecimalgt . transact id kr ltgt .',
#  'goodmorn sleep ga.',
#  'u call alter 11 ok.',
#  'ìï say like dat dun buy ericsson oso cannot oredi lar...',
#  'enter cabin pa said happi bday bos . felt special. askd 4 lunch. lunch invit apartment. went there.',
#  'aight yo dat straight dogg',
#  'plea give u connect today ltdecimalgt refund bill',
#  'shoot big load get readi',
#  'what bruv hope great break. reward semester.',
#  'home alway chat',
#  'kkgoodstudi well.',
#  'yup... ì_ noe leh...',
#  'sound great home',
#  'final match head toward draw prediction.',
#  'tired. havent slept well past nights.',
#  'easi ahsen got select mean good..',
#  'take exam march 3',
#  'yeah should. think use gt atm register. sure there anyway help let know. sure ready.',
#  'ok prob. take ur time.',
#  'o call ubandu run without instal hard disk...you use o copi import file system give repair shop..',
#  'sorri ill call later',
#  'u say leh... cours noth happen lar. say v romant ju bit lor. thk e nite sceneri nice leh.',
#  '500 new mobil 2004 must go txt nokia 89545 collect todayfrom å1 www.4tc.biz 2optout 087187262701.50gbp/mtmsg18',
#  'would realli appreci call me. need someon talk to.',
#  'u meet ur dream partner soon ur career 2 flyng start 2 find free txt horo follow ur star sign e. g. horo ari',
#  'hey compani elama po mudyadhu.',
#  'life strict teacher... bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lessons. happi morning. . .',
#  'dear good morn',
#  'get gandhipuram walk cross cut road. right side ltgt street road turn first right.',
#  'dear go rubber place',
#  'sorri batteri die yeah im',
#  'yesher tv alway avail work place..',
#  'text meet someon sexi today. u find date even flirt u. join 4 10p. repli name age eg sam 25. 18 msg recdthirtyeight penc',
#  'print oh. ltgt come upstair',
#  'ill littl closer like bu stop street',
#  'youwhen wil reach',
#  'new theori argument win situat lose person. dont argu ur friend just.. . . . kick amp say im alway correct.',
#  'u 447801259231 secret admir look 2 make contact ufind rreveal think ur specialcal 09058094597',
#  'tomarrow final hear laptop case cant.',
#  'pleassssssseeeee tel v avent done sportsx',
#  'okay. shine on. meant sign sound better.',
#  'although told u dat im baig face watch realli like e watch u gave co fr u. thanx 4 everyth dat uve done today im touched...',
#  'u dont rememb old commerci',
#  'late. said website. didnt dont slipper',
#  'ask call ok',
#  'kalli wont bat 2nd innings.',
#  'didnt work oh. ok goodnight then. i.ll fix readi time wake up. dearli miss good night sleep.',
#  'congratul ur award 500 cd voucher 125gift guarante free entri 2 100 wkli draw txt music 87066 tnc www.ldew.com1win150ppmx3age16',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'wen ur lovabl bcum angri wid u dnt take seriously.. coz angri childish n true way show deep affect care n luv.. kettoda manda... nice day da.',
#  'doinghow',
#  'up 3day also ship compani take 2wks. way usp take week get lag may bribe nipost get stuff.',
#  'im back lemm know your readi',
#  'dont necessarili expect done get back though im headin',
#  'mmm yummi babe ... nice jolt suzi',
#  'lover need ...',
#  'tri contact repli offer video handset 750 anytim network min unlimit text camcord repli call 08000930705',
#  'iûṫm park next mini come today think',
#  'yup',
#  'anyway im go shop now. co si done yet. dun disturb u liao.',
#  'no. luton 0125698789 ring ur around h',
#  'hey realli horni want chat see nake text hot 69698 text charg 150pm unsubscrib text stop 69698',
#  'dint come us.',
#  'same. wana plan trip sometm',
#  'sure yet still tri get hold',
#  'ur rington servic chang 25 free credit go club4mobiles.com choos content stop txt club stop 87070. 150p/wk club4 po box1146 mk45 2wt',
#  'evo. download flash. jealou',
#  'rington club get uk singl chart mobil week choos top qualiti rington messag free charge.',
#  'come mu sort narcot situat',
#  'night end anoth day morn come special way. may smile like sunni ray leav worri blue blue bay.',
#  'hmv bonu special 500 pound genuin hmv voucher won. answer 4 easi questions. play send hmv 86688 infowww.100percentreal.com',
#  'usf guess might well take 1 car',
#  'objection. bf coming.',
#  'thanx...',
#  'tell rob mack gf theater',
#  'awesom ill see bit',
#  'sent it. type food like',
#  'done hand celebr full swing yet',
#  'got call tool',
#  'wen u miss someon',
#  'ok. ask money far',
#  'okie...',
#  'yeah think usual guy still pas last night get ahold anybodi let know ill throw',
#  'k might come tonight class let earli',
#  'ok..',
#  'hi babi im cruisin girl friend r u 2 give call hour home that alright fone fone love jenni xxx',
#  'life mean lot love life love peopl life world call friend call world.. ge..',
#  'dearshal mail tonite.busi streetshal updat tonite.th look ok.varunnathu edukkukaye raksha ollu.but good one real sense.',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam working.',
#  'oops. 4 got bit.',
#  'much buzi',
#  'accident delet message. resend please.',
#  'tmobil custom may claim free camera phone upgrad pay go sim card loyalty. call 0845 021 3680.offer end 28thfeb.tc appli',
#  'unless situat go gurl would appropri',
#  'hurt me... tea me... make cry... end life die plz keep one rose grave say stupid miss u.. nice day bslvyl',
#  'cant pick phone right now. pl send messag',
#  'need coffe run tomoc believ time week alreadi',
#  'awesom rememb last time got somebodi high first time diesel v',
#  'shit realli shock scari cant imagin second. def night out. u think somewher could crash night save taxi',
#  'oh way food fridg want go meal tonight',
#  'womdarful actor',
#  'sms. ac blind date 4u rodds1 21/m aberdeen unit kingdom. check http//img. sms. ac/w/icmb3cktz8r74 blind date send hide',
#  'yup... remb... think book...',
#  'jo ask u wana meet',
#  'lol yes. friendship hang thread caus u wont buy stuff.',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap 82468',
#  'garag key arent bookshelf',
#  'today accept day..u accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#  'think ur smart win å200 week weekli quiz text play 85222 nowtc winnersclub po box 84 m26 3uz. 16. gbp1.50/week',
#  'say hell give call friend got money he definit buy end week',
#  'hi way u 2day normal waythi real me. ur uniquei hope know u 4 rest mylife. hope u find wot lost.',
#  'made day. great day too.',
#  'k.kadvanc happi pongal.',
#  'hmmm... guess go 4 kb n power yoga... haha dunno tahan power yoga anot... thk got lo oso forgot liao...',
#  'realli dude friend im afraid',
#  'decemb mobil 11mth entitl updat latest colour camera mobil free call mobil updat co free 08002986906',
#  'coffe cake guess...',
#  'merri christma babe love ya kiss',
#  'hey... dont go watch x men lunch... haha',
#  'cud u tell ppl im gona b bit l8 co 2 buse hav gon past co full im still waitin 4 1. pete x',
#  'would great. well guild. could meet bristol road somewher get touch weekend. plan take flight good week',
#  'problem.',
#  'calls..messages..miss call',
#  'hi dahow today class',
#  'id say that good sign well know track record read woman',
#  'cool text your park',
#  'im read text sent you. meant joke. read light',
#  'k.kapo k.good movie.',
#  'mayb could get book tomo return immedi .. something.',
#  'call germani 1 penc per minut call fix line via access number 0844 861 85 85. prepayment. direct access',
#  'chanc might evapor soon violat privaci steal phone number employ paperwork. cool all. plea contact report supervisor.',
#  'valentin day special win å1000 quiz take partner trip lifetim send go 83600 now. 150p/msg rcvd. custcare08718720201.',
#  'tadaaaaa home babe still',
#  'cool. come havent wine dine',
#  'sleeping..and surf',
#  'sorri ill call later',
#  'u call right call hand phone...',
#  'ok that great thanx lot.',
#  'take post come must 1000 text happi reading. one wiv hello carolin end favourite. bless',
#  'u hide stranger',
#  'interest like that.',
#  'sister clear two round birla soft yesterday.',
#  'gudnite....tc...practic go',
#  'di yijue. ju saw ur mail. case huim havent sent u num. di num.',
#  'one small prestig problem now.',
#  'fanci shag do.interest sextextuk.com txt xxuk suzi 69876. txt cost 1.50 per msg. tnc website. x',
#  'check you. realli miss see jeremiah. great month',
#  'nah cant help ive never iphon',
#  'your car hour half im go apeshit',
#  'today sorri day. ever angri ever misbehav hurt plz plz slap urself bcoz ur fault im basic good',
#  'yo guy ever figur much need alcohol jay tri figur much safe spend weed',
#  'ltgt ish minut 5 minut ago. wtf.',
#  'thank calling.forgot say happi onam sirji.i fine rememb met insur person.meet qatar insha allah.rakhesh ex tata aig join tisscotayseer.',
#  'congratul ur award 500 cd voucher 125gift guarante free entri 2 100 wkli draw txt music 87066 tnc www.ldew.com1win150ppmx3age16',
#  'ur cashbal current 500 pound maxim ur cashin send cash 86688 150p/msg. cc 08708800282 hg/suite342/2land row/w1j6hl',
#  'im actor. work work even sleep late. sinc im unemploy moment alway sleep late. your unemploy everi day saturday.',
#  'hello got st andrewsboy long way cold. keep post',
#  'ha ha cool cool chikku chikkudb',
#  'oh ok prob..',
#  'check audrey statu right',
#  'busi here. tri finish new year. look forward final meet you...',
#  'good afternoon sunshin dawn day refresh happi aliv breath air smile think love ... alway',
#  'well know z take care me. worries.',
#  'update_now xma offer latest motorola sonyericsson nokia free bluetooth doubl min 1000 txt orange. call mobileupd8 08000839402 call2optout/f4q',
#  'discount code rp176781. stop messag repli stop. www.regalportfolio.co.uk. custom servic 08717205546',
#  'wat uniform get',
#  'cool text your readi',
#  'hello boytoy ... geeee miss alreadi woke up. wish bed cuddl me. love ...',
#  'spoil bed well',
#  'im go bath msg next ltgt min..',
#  'cant keep talk peopl sure pay agre price. pl tell want realli buy much will pay',
#  'thank rington order refer t91. charg gbp 4 per week. unsubscrib anytim call custom servic 09057039994',
#  'say happen',
#  'could seen me..i didt recognis face.',
#  'well there lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#  'keep payasam rinu bring',
#  'taught ranjith sir call me. sm like that. becau he verifi project. prabu told today pa dont mistak me..',
#  'guess that worried. must know there way bodi repair itself. im quit sure shouldnt worry. well take slow. first test guid ovul relax. noth youv said reason worri i.ll keep followin up.',
#  'yeah sure give coupl minut track wallet',
#  'hey leav it. big deal take care.',
#  'hey late ah... meet 945',
#  'doubl min txt 4 6month free bluetooth orange. avail soni nokia motorola phones. call mobileupd8 08000839402 call2optout/n9dx',
#  'took mr owl 3 lick',
#  'custom place call you.',
#  'mm time dont like fun',
#  '4mth half price orang line rental latest camera phone 4 free. phone 11mth call mobilesdirect free 08000938767 updat or2stoptxt',
#  'yup lunch buffet now.. u eat alreadi',
#  'huh late... fr dinner',
#  'hey sat go intro pilat kickbox',
#  'morn ok.',
#  'ye think so. offic lap room think that last days. didnt shut',
#  'pick bout 7.30ish time go',
#  'perform award calcul everi two month.not current one month period..',
#  'actual sleep still might u call back. text gr8. rock sis. send u text wen wake.',
#  'alway put busi there. put pictur as facebook. one open peopl ive ever met. would think pictur room would hurt make feel violated.',
#  'good even sir al salam wahleykkum.shar happi news.bi grace god got offer tayseertissco joined.hop fine.inshah allahmeet sometime.rakheshvisitor india.',
#  'hmmm...k...but want chang field quickli dai wanna get system administr network administrator..',
#  'free rington text first 87131 poli text get 87131 true tone help 0845 2814032 16 1st free tone 3xå150pw eånd txt stop',
#  'dear chechi. talk',
#  'hair cream shipped.',
#  'none that happen til get though',
#  'yep great loxahatche xma tree burn ltgt start hour',
#  'haha get use drive usf man know lot stoner',
#  'well slightli disastr class pm fav darl hope day ok. coffe wld good cant stay late tomorrow. time place alway',
#  'hello good week fanci drink someth later',
#  'headin toward busetop',
#  'messagesom text miss sendernam miss number miss sentdat miss miss u lot that everyth miss sent via fullonsms.com',
#  'come room point iron plan weekend',
#  'co want thing',
#  'okies... ill go yan jiu too... skip ard oso go cine den go mrt one blah blah blah...',
#  'bring home wendi',
#  '100 date servic call 09064012103 box334sk38ch',
#  'whatsup there. dont u want sleep',
#  'alright new goal',
#  'free entri å250 weekli competit text word win 80086 now. 18 tc www.txttowin.co.uk',
#  'alright ill head minut text meet',
#  'send logo 2 ur lover 2 name join heart. txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo pobox36504w45wq txtno 4 ad 150p',
#  'yesfrom last week im take live call.',
#  'someon contact date servic enter phone fanci find call landlin 09111032124 . pobox12n146tf150p',
#  'siva hostel aha.',
#  'urgent mobil number award å2000 prize guaranteed. call 09058094455 land line. claim 3030. valid 12hr',
#  'send ur friend receiv someth ur voice..... speak express 1.childish 2.naughti 3.sentiment 4.rowdi 5.ful attitud 6.romant 7.shi 8.attract 9.funni ltgt .irrit ltgt .lovable. repli me..',
#  'ok. shell ok. guess',
#  'aathi..wher dear..',
#  'pain urin thing el',
#  '7 esplanade.. ì_ mind give lift co got car today..',
#  'wnt buy bmw car urgently..it vri urgent.but hv shortag ltgt lacs.ther sourc arng di amt. ltgt lacs..that prob',
#  'home watch tv lor.',
#  'usual take fifteen fuck minut respond ye question',
#  'congrat nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3min vari mobil 16 close 300603 post bcm4284 ldn wc1n3xx',
#  'book ticket pongal',
#  'avail im like right around hillsborough amp ltgt th',
#  'messag sent askin ltgt dollars. shoul pay ltgt ltgt',
#  'ask g iouri ive told stori like ten time alreadi',
#  'long applebe fuck take',
#  'hi hope u get txtjourney hasnt gdnow 50 min late think.',
#  'to. like love arrange.',
#  'yes..h realli great..bhaji told kalli best cricket sachin world.veri tough get out.',
#  'suppos wake gt',
#  'oic... saw tot din c me... found group liao...',
#  'sorri ill call later',
#  'hey hey wereth monkeespeopl say monkeyaround howdi gorgeou',
#  'sorri batteri die come im get gram where place',
#  'well done blimey exercis yeah kinda rememb wot hmm.',
#  'wont get concentr dear know mind everyth',
#  'lol ... made plan new year',
#  '10 min later k...',
#  'hank lotsli',
#  'thank hope good day today',
#  'kkwhat detail want transferacc enough',
#  'ok tell stay out. yeah tough optimist thing improv month.',
#  'loan purpos å500 å75000. homeown tenant welcome. previous refus still help. call free 0800 1956669 text back help',
#  'si si. think ill go make oreo truffles.',
#  'look ami ure beauti intellig woman like u lot. know u donåõt like like donåõt worry.',
#  'hope that result consist intellig kind. start ask practicum link keep ear open best. ttyl',
#  '1.20 call cost. guess isnt bad. miss ya need ya want ya love ya',
#  'go thru differ feeling.wav decis cope individual.tim heal everyth believe.',
#  'u go phone gonna die stay',
#  'great. never better. day give even reason thank god',
#  'upgrdcentr orang custom may claim free camera phone upgrad loyalty. call 0207 153 9153. offer end 26th july. tc apply. optout avail',
#  'sorri ill call later ok bye',
#  'ok way railway',
#  'great princess love give receiv oral. doggi style fave position. enjoy make love ltgt time per night',
#  'dont put stuff road keep get slipperi',
#  'go ride bike',
#  'yup need. ill ju wait 4 e rain 2 stop.',
#  'mani company. tell language.',
#  'okmail dear dave final notic collect 4 tenerif holiday 5000 cash award call 09061743806 landline. tc sae box326 cw25wx 150ppm',
#  'long sinc scream princess',
#  'nothing. meant money enter account bank remov flat rate. someon transfer ltgt account ltgt dollar got removed. bank differ charg also differ.b sure trust 9ja person send account detail cos...',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network txting moan 69888nyt. ec2a. 31p.msg150p',
#  'nice line said broken heart plz dont cum 1 time infront me... wise trust u... good 9t',
#  'ok im gonna head usf like fifteen minut',
#  'love aathi..lov u lot..',
#  'tension ahwhat machiani problem',
#  'k pick anoth 8th your done',
#  'whenr guy get back g said think stay mcr',
#  'almost see u sec',
#  'yo carlo friend alreadi ask work weekend',
#  'watch tv lor...',
#  'thank babi cant wait tast real thing...',
#  'chang fb jaykwon thuglyf falconerf',
#  'win realli 1 side long time.',
#  'free messag activ 500 free text messag repli messag word free term condit visit www.07781482378.com',
#  'dear reach railway. happen',
#  'depend quality. want type sent boy fade glori 6. want ralph mayb 2',
#  'think ive fix send test messag',
#  'sorri man account dri would want could trade back half could buy shit credit card',
#  'congrat 1 year special cinema pas 2 yours. call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45we. 150pm. dont miss',
#  'sorryin meet ill call later',
#  'class ltgt reunion',
#  'free nowcan call',
#  'got meh...',
#  'nope... think go monday... sorri repli late',
#  'told accentur confirm. true.',
#  'kate jackson rec center 7ish right',
#  'dear reach room',
#  'fight world easi u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose.',
#  'ì_ come',
#  'check nuerologist.',
#  'lolnice. went fish ..water.',
#  '123 congratul week competit draw u å1450 prize claim call 09050002311 b4280703. tcs/stop sm 08718727868. 18 150ppm',
#  'wait e car dat bore wat. co wait outsid got noth 2 do. home stuff watch tv wat.',
#  'mayb westshor hyde park villag place near hous',
#  'know now. how anthony. bring money. ive school fee pay rent stuff like that. that need help. friend need....',
#  'what signific',
#  'opinion 1. 2. jada 3. kusruthi 4. lovabl 5. silent 6. spl charact 7. matur 8. stylish 9. simpl pl reply..',
#  '8 latest g still scroung ammo want give new ak tri',
#  'prabha..im soryda..realy..frm heart im sorus',
#  'lol ok forgiven',
#  'no..jst chang tat only..',
#  'guarante latest nokia phone 40gb ipod mp3 player å500 prize txt word collect 83355 ibhltd ldnw15h 150p/mtmsgrcvd18',
#  'sno competit him.',
#  'boltblu tone 150p repli poli mono eg poly3 1. cha cha slide 2. yeah 3. slow jamz 6. toxic 8. come stop 4 tone txt',
#  'credit top http//www.bubbletext.com renew pin tgxxrz',
#  'way transport le problemat sat night. way u want ask n join bday feel free. need know definit no book fri.',
#  'usual person unconsci that child adult may behav abnormally. i.ll call',
#  'that ebay might le elsewhere.',
#  'shall come get pickl',
#  'gonna go get taco',
#  'that rude campu',
#  'urgent mobil no. award å2000 bonu caller prize 02/09/03 2nd attempt contact call 08718729755 box95qu',
#  'hi wont b ard 4 christmas. enjoy n merri xmas.',
#  'today offer claim ur å150 worth discount voucher text ye 85023 savamob member offer mobil c 08717898035. å3.00 sub. 16 . unsub repli x',
#  'ye pretti ladi like singl',
#  'reciev tone within next 24hrs. term condit plea see channel u teletext pg 750',
#  'jay say your doublefaggot',
#  'privat 2003 account statement 07815296484 show 800 unredeem s.i.m. points. call 08718738001 identifi code 41782 expir 18/11/04',
#  'todaysunday..sunday holiday..so work..',
#  'gudnite....tc...practic go',
#  'ill late...',
#  'ive call while. hope l8r malaria know miss guys. miss ban big pl give love especially. great day.',
#  'good afternoon love goe day hope mayb got lead job. think boytoy send passion kiss across sea',
#  'probabl gonna see later tonight lt',
#  'mayb fat finger press button doesnt know do.',
#  'ummmmmaah mani mani happi return day dear sweet heart.. happi birthday dear',
#  'tirupur da start offic call me.',
#  'www.applausestore.com monthlysubscription50p/msg max6/month tcsc web age16 2stop txt stop',
#  'famou quot develop abil listen anyth uncondit without lose temper self confid mean ......... marri',
#  'go colleg pa. do. el ill come self. pa.',
#  '4 oclock mine. bash flat plan.',
#  'girl stay bed. girl doesnt need recoveri time. id rather pas fun coop bed',
#  'special',
#  'know need get hotel now. got invit apologise. cali sweet come english bloke weddin',
#  'sorri took long omw',
#  'wait ltgt min..',
#  'ok give 5 minut think see her. btw your alibi. cut hair whole time.',
#  'imagin final get sink bath put pace mayb even eat left ... also imagin feel cage cock surround bath water remind alway own ... enjoy cuck',
#  'hurri ive weeddefici like three day',
#  'sure get acknowledg astoundingli tactless gener faggi demand blood oath fo',
#  'ok. everi night take warm bath drink cup milk youll see work magic. still need loo weight. know',
#  'iûṫll look fri pan case itûṫ cheap book perhaps. thatûṫ silli fri pan isnûṫt like book',
#  'o. well uv caus mutations. sunscreen like essenti theseday',
#  'lunchyou onlinewhi',
#  'know friend alreadi told that.',
#  'hi princess thank pics. pretty.',
#  'aiyo... u alway c ex one... dunno abt mei reply... first time u repli fast... lucki workin huh got bao ur sugardad ah...gee..',
#  'hi msg meim office..',
#  'thanx 4 e browni v nice...',
#  'geeeee ... love much bare stand',
#  'gent tri contact you. last weekend draw show å1000 prize guaranteed. call 09064012160. claim code k52. valid 12hr only. 150ppm',
#  'fuck babe ... miss alreadi know cant let send money toward net need ... want ... crave ...',
#  'ill call u 2mrw ninish address icki american freek wont stop callin 2 bad jen k eh',
#  'oooh bed ridden ey think',
#  'anyway go gym whatev love smile hope ok good day babe ... miss much alreadi',
#  'love daddi make scream pleasur go slap as dick',
#  'wot u wanna missi',
#  'yar lor wait 4 mum 2 finish sch lunch lor... whole morn stay home clean room room quit clean... hee...',
#  'know lab goggl went',
#  'open door',
#  'wait call.',
#  'nope wait sch 4 daddy...',
#  '1000 cash 2000 prize claim call09050000327',
#  'im tire argu week week. want ill same.',
#  'ìï wait 4 sch finish ard 5..',
#  'mobil number å5000 claim call u back ring claim hot line 09050005321.',
#  'arngd marriag u r walkin unfortuntli snake bite u. bt love marriag danc frnt snake amp sayin bite bite me.',
#  'huh early.. ì_ dinner outsid izzit',
#  'ok anyway need chang said',
#  'tri contact repli offer 750 min 150 textand new video phone call 08002988890 repli free deliveri tomorrow',
#  'exwif abl kids. want kid one day',
#  'how scotland. hope show jjc tendencies. take care. live dream',
#  'tell u headach want use 1 hour sick time.',
#  'dun thk ill quit yet... hmmm go jazz yogasana oso can... go meet em lesson den...',
#  'pete plea ring meiv hardli gotani credit',
#  'ya srsli better yi tho',
#  'im meet call later',
#  'ur chanc win å250 wkli shop spree txt shop 80878. tsc www.txt2shop.com custcar 08715705022 1x150p/wk',
#  'special select receiv 2000 pound award call 08712402050 line close. cost 10ppm. 16. tc apply. ag promo',
#  'privat 2003 account statement 07753741225 show 800 unredeem s. i. m. points. call 08715203677 identifi code 42478 expir 24/10/04',
#  'still grand prix',
#  'met stranger choos friend. long world stand friendship never ends. let friend forev gud nitz...',
#  'great',
#  'gud mrng dear nice day',
#  'import custom servic announcement. call freephon 0800 542 0825',
#  'do. exhaust train morning. much wine pie. sleep well',
#  'im go buy mum present ar.',
#  'mind blastin.. tsunami occur on.. rajnik stop swim indian ocean..d',
#  'u send home first ok lor. im readi yet.',
#  'speak cash yet',
#  'happi there. come noon',
#  'meet lunch la...',
#  'take care n get well soon',
#  'xclusiveclubsaisai 2morow 28/5 soire special zouk nichol paris.fre rose 2 ladi info 07946746291/07880867867',
#  'meant say cant wait see u get bore bridgwat banter',
#  'neva mind ok..',
#  'fine imma get drink somethin. want come find',
#  '22 day kick euro2004 u kept date latest news result daily. remov send get txt stop 83222',
#  'valentin game. . . send di msg ur friends. .. 5 answer r someon realli love u. que colour suit bestrpli',
#  'mani depend',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soon.c',
#  'call said himthen choos future.',
#  'happi valentin day know earli hundr handsom beauti wish. thought finish aunti uncl 1st...',
#  'like v shock leh. co tell shuhui like tell leona also. like dat almost know liao. got ask abt ur reaction lor.',
#  'famili happiness..',
#  'come n pick ì_ up... come immedi aft ur lesson...',
#  'let snow. let snow. kind weather bring ppl togeth friendship grow.',
#  'dear got ltgt dollar hi hi',
#  'good words.... word may leav u dismay mani times.',
#  'make sure alex know birthday fifteen minut far your concern',
#  'sorri got thing do. may pub later.',
#  'nah straight bring bud drink someth that actual littl use straight cash',
#  'haha good hear im offici paid market 8th',
#  'mani lick take get center tootsi pop',
#  'yup thk r e teacher said make face look longer. darren ask 2 cut short.',
#  'new textbuddi chat 2 horni guy ur area 4 25p free 2 receiv search postcod gaytextbuddy.com. txt one name 89693',
#  'today vodafon number end 4882 select receiv å350 award. number match call 09064019014 receiv å350 award.',
#  'plea dont say like that. hi hi hi',
#  'thank u',
#  'oh forward message. thought send',
#  'got it. seventeen pound seven hundr ml ûò hope ok.',
#  'dear voucher holder 2 claim week offer pc go http//www.etlp.co.uk/expressoff tsc apply.2 stop text txt stop 80062.',
#  'n funny...',
#  'sweetheart hope kind day one load reason smile. biola',
#  'ì_ login dat time... dad fetch ì_ home',
#  'shower babi',
#  'askd u question hour before. answer',
#  'well imma definit need restock thanksgiv ill let know im',
#  'said kiss kiss cant sound effect gorgeou man isnt kind person need smile brighten day',
#  'probabl gonna swing wee bit',
#  'ya nice. . .be readi thursday',
#  'allo brave buse taken train triumphed. mean weûṫr bûṫham. jolli good rest week',
#  'watch cartoon listen music amp eve go templ amp church.. u',
#  'mind ask happen dont say uncomfortable.',
#  'privat 2003 account statement show 800 unredeem s. i. m. points. call 08715203694 identifi code 40533 expir 31/10/04',
#  'prob. send email.',
#  '1000 cash 2000 prize claim call09050000327. tc rstm sw7 3ss. 150ppm',
#  'that cool sometim slow gentle. sonetim rough hard',
#  'im gonna say no. sorry. would normal start panic time. sorri see tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much.',
#  'u got person stori',
#  'tell drug dealer get impati',
#  'sun cant come earth send luv rays. cloud cant come river send luv rain. cant come meet u send care msg u. gud evng',
#  'place man',
#  'doesnt make sen take unless free. need know wikipedia.com',
#  '88800 89034 premium phone servic call 08718711108',
#  'sea lay rock. rock envelope. envelop paper. paper 3 words...',
#  'mum repent',
#  'sorri go home first... daddi come fetch ì_ later...',
#  'leav de. start prepar next..',
#  'ye babi studi posit kama sutra',
#  'en chikku nang bakra msg kalstiya..then tea/coffe',
#  'carlosl minut still need buy',
#  'pay ltdecimalgt lakh',
#  'good even ttyl',
#  'u receiv msg',
#  'ho ho big belli laugh see ya tomo',
#  'sms. ac sun0819 post helloy seem cool',
#  'get ur 1st rington free repli msg tone. gr8 top 20 tone phone everi week å1.50 per wk 2 opt send stop 08452810071 16',
#  'ditto. wont worri say anyth anymore. like said last night whatev want ill same. peace.',
#  'ive got ltgt way could pick',
#  'dont knw pa drink milk..',
#  'mayb say hi find got card. great escap wetherspoon',
#  'piggi r u awak bet ure still sleeping. im go 4 lunch now...',
#  'caus im freaki lol',
#  'miss call caus yell scrappy. miss u. cant wait u come home. im lone today.',
#  'hex place talk explain',
#  'ìï log 4 wat. sdryb8i',
#  'xy go 4 e lunch',
#  'hi im sue. 20 year old work lapdancer. love sex. text live im bedroom now. text sue 89555. textoper g2 1da 150ppmsg 18',
#  'want ask ì_ wait 4 finish lect. co lect finish hour anyway.',
#  'finish work yet',
#  'everi king cri babi everi great build map.. imprtant u r today u wil reach tomorw. gud ni8',
#  'dearm cherthala.in case u r come cochin pl call bfore u start.i shall also reach accordingly.or tell day u r coming.tmorow engag an holiday.',
#  'thank love. torch bold.',
#  'forward 448712404000pleas call 08712404000 immedi urgent messag wait you.',
#  'farm open',
#  'sorri troubl u again. buy 4d dad 1405 1680 1843. 2 big 1 small sat n sun. thanx.',
#  'sister law hope great month. say hey. abiola',
#  'purchas stuff today mail you. po box number',
#  'ah poop. look like ill prob send laptop get fix cuz gpu problem',
#  'good. good job. like entrepreneur',
#  'aight close still around alex place',
#  'meet corpor st outsid gap û_ see mind work',
#  'mum ask ì_ buy food home...',
#  'k..u also dont msg repli msg..',
#  'much r ì_ will pay',
#  'sorri ill call later',
#  'import prevent dehydr give enough fluid',
#  'that bit weird even suppos happen good idea sure pub',
#  'true dear..i sat pray even felt so.so smsd time...',
#  'dont think get away trek long famili town sorri',
#  'wanna gym harri',
#  'quit late lar... ard 12 anyway wun b drivin...',
#  'review keep fantast nokia ngage game deck club nokia go 2 www.cnupdates.com/newsletter. unsubscrib alert repli word',
#  '4mth half price orang line rental latest camera phone 4 free. phone 11mth call mobilesdirect free 08000938767 updat or2stoptxt tc',
#  'height confid aeronaut professor wer calld amp wer askd 2 sit aeroplane. aftr sat wer told dat plane w made students. dey hurri plane.. bt 1 didnt move... saidif made student',
#  'seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#  '08714712388 10am7pm cost 10p',
#  'save stress. person dorm account send account detail money sent you.',
#  'also know lunch menu da. . know',
#  'stuff sell i.ll tell',
#  '449071512431 urgent 2nd attempt contact uu å1250 call 09071512433 b4 050703 tcsbcm4235wc1n3xx. callcost 150ppm mobilesvary. maxå7. 50',
#  'book lesson msg me... call work sth... im go get specs. membership px3748',
#  'guarante å1000 cash å2000 prize. claim yr prize call custom servic repres 08714712394 10am7pm',
#  'macha dont feel upset.i assum mindset.believ one even wonder plan us.let life begin again.cal anytim',
#  'oh send address',
#  'sfine. anytime. best it.',
#  'wondar full flim.',
#  'ya even cooki jelli',
#  'world run still.mayb feel sameso it.or admiti mad.then correctionor let call life.and keep run worldmay u r also running.let run.',
#  'got look scrumptious... daddi want eat night long',
#  'co lar im ba dao ok... 1 pm lor... u never ask go ah... said u would ask fri said u ask today...',
#  'alright omw gotta chang order half8th',
#  'exactly. anyway far. jide studi visit',
#  'dunno u ask me.',
#  'email alertfrom jeri stewart 2kbsubject lowcost prescripiton drvgsto listen email call 123',
#  'didnt. spring come earli yay',
#  'lol wont feel bad use money take steak dinner',
#  'even u dont get troubl convincing..just tel twice tel neglect msg dont c read it..just dont repli',
#  'leav qatar tonit search opportunity.al went fast.pl add ur prayer dear.rakhesh',
#  'one talk',
#  'thank look me. realli appreciate.',
#  'hi. custom loyalti offerth new nokia6650 mobil å10 txtauction txt word start 81151 get 4tctxt tc 150p/mtmsg',
#  'wish',
#  'haha mayb ure rite... u know well. da feel like someon gd lor. u faster go find one gal group attach liao.',
#  'ye there. glad made it.',
#  'well littl time. thing good time ahead',
#  'got up. room soon. û_. hadnt put clock back til 8 shout everyon get realis 7. wahay. anoth hour bed.',
#  'ok. may free gym about.',
#  'men like shorter ladies. gaze eyes.',
#  'dunno ju say go lido. time 930.',
#  'promis take good care princess. run now. plea send pic get chance. ttyl',
#  'u subscrib best mobil content servic uk å3 per 10 day send stop 82324. helplin 08706091795',
#  'reason weve spoken year anyway great week best exam',
#  'monday next week. give full gist',
#  'realiz 40 year well thousand old ladi run around tattoo',
#  'import custom servic announc premier.',
#  'dont gimm lip caveboy',
#  'get librari',
#  'reali sorryi dont recognis number confus r u plea',
#  'didnt holla',
#  'cant think anyon spare room top head',
#  'faith make thing possiblehop make thing worklov make thing beautifulmay three christmasmerri christma',
#  'u made appoint',
#  'call you/carlo is/ar phone vibrat act might hear text',
#  'romant paris. 2 night 2 flight å79 book 4 next year. call 08704439680tsc apply.',
#  'grandmas. oh dear u still ill felt shit morn think hungov anoth night then. leav sat.',
#  'urgent ur å500 guarante award still unclaim call 09066368327 closingdate04/09/02 claimcod m39m51 å1.50pmmorefrommobile2bremovedmobypobox734ls27yf',
#  'noth ju tot u would ask co u ba gua... went mt faber yest... yest ju went alreadi mah today go out... ju call lor...',
#  'wish famili merri x ma happi new year advance..',
#  'ur award citi break could win å200 summer shop spree everi wk. txt store 88039 . skilgme. tscs087147403231winawkage16 å1.50perwksub',
#  'im nt goin got somethin unless meetin 4 dinner lor... haha wonder go ti time...',
#  'sorri ill call later',
#  'cant pick phone right now. pl send messag',
#  'lol know theyr dramatic. school alreadi close tomorrow. appar cant drive inch snow suppos get.',
#  'get anywher damn job hunt',
#  'lol u drunkard hair moment. yeah still 4 tonight. wat plan',
#  'idc get weasel way shit twice row',
#  'wil ltgt minutes. got space',
#  'sleeping..and surf',
#  'thank pick trash.',
#  'dont go tell friend your sure want live smoke much spend hour beg come smoke',
#  'hi kate love see tonight ill phone tomorrow. got sing guy gave card xxx',
#  'happi new year dear brother. realli miss you. got number decid send text wish happiness. abiola',
#  'mean get door',
#  'opinion 1. 2. jada 3. kusruthi 4. lovabl 5. silent 6. spl charact 7. matur 8. stylish 9. simpl pl reply..',
#  'hmmm ... thought said 2 hour slave 3 ... late ... punish',
#  'beerag',
#  'import custom servic announc premier. call freephon 0800 542 0578',
#  'dont think so. turn like randomlli within 5min open',
#  'suppos couldnt make she still town though',
#  'own. time fix spelling. sometim get complet diff word. go figur',
#  'ever thought live good life perfect partner txt back name age join mobil community. 100p/sm',
#  '5 free top polyphon tone call 087018728737 nation rate. get toppoli tune sent everi week text subpoli 81618 å3 per pole. unsub 08718727870.',
#  'gud mrng dear hav nice day',
#  'hope enjoy game yesterday. sorri ive touch pl know fondli bein thot off. great week. abiola',
#  'e best 4 ur drive tmr',
#  'ywhere u dogbreath sound like jan c thatåõ al',
#  'omg want scream. weigh lost weight woohoo',
#  'gener isnt one. uncount noun u dictionary. piec research',
#  'realli get hang around.',
#  'orang custom may claim free camera phone upgrad loyalty. call 0207 153 9996. offer end 14thmarch. tc apply. optout availa',
#  'petey boy wherear friendsar thekingshead come canlov nic',
#  'ok msg u b4 leav house.',
#  'gimm ltgt minut ago',
#  'last chanc claim ur å150 worth discount voucher today text shop 85023 savamob offer mobil c savamob pobox84 m263uz. å3.00 sub. 16',
#  'appt lttimegt am. fault u dont listen. told u twice',
#  'free 1st week no1 nokia tone 4 ur mobil everi week txt nokia 8077 get txting tell ur mates. www.getzed.co.uk pobox 36504 w45wq 16 norm150p/ton',
#  'guarante å200 award even å1000 cashto claim ur award call free 08000407165 18 2 stop getstop 88222 php. rg21 4jx',
#  'k ill 4.',
#  'dled 3d imp',
#  'sure make sure know aint smokin yet',
#  'boooo alway work. quit.',
#  'take half day leav bec well',
#  'ugh dont wanna get bed. warm.',
#  'ss.nervou ltgt',
#  'there ring come guy costumes. gift futur yowifes. hint hint',
#  'congratul ur award either å500 cd gift voucher free entri 2 å100 weekli draw txt music 87066 tnc www.ldew.com1win150ppmx3age16',
#  'borrow ur bag ok.',
#  'u outbid simonwatson5120 shinco dvd plyr. 2 bid visit sms. ac/smsreward 2 end bid notif repli end',
#  'where boytoy miss ... happen',
#  'lot use one babe model doesnt help. youi bring hell match',
#  'also bring galileo dobbi',
#  'respond',
#  'boo babe u enjoyin yourjob u seem 2 b gettin well hunnyhop ure oktak care iåõllspeak 2u soonlot lovem xxxx.',
#  'good afternoon starshin how boytoy crave yet ach fuck sip cappuccino miss babe tea kiss',
#  'road cant txt',
#  'smsservices. yourinclus text credit pl goto www.comuk.net login 3qxj9 unsubscrib stop extra charge. help 08702840625.comuk. 220cm2 9ae',
#  '25p 4 alfi moon child need song ur mob. tell ur m8s. txt tone chariti 8007 nokia poli chariti poli zed 08701417012 profit 2 charity.',
#  'good even ttyl',
#  'hmm .. bit piec lol ... sigh ...',
#  'hahaha..us brain dear',
#  'hey. got mail',
#  'sorri light turn green meant anoth friend want ltgt worth may around',
#  'thank yesterday sir. wonderful. hope enjoy burial. mojibiola',
#  'u secret admirer. reveal think u r special. call 09065174042. opt repli reveal stop. 1.50 per msg recd. cust care 07821230901',
#  'hi mate rv u hav nice hol messag 3 say hello coz havenåõt sent u 1 age start drive stay roadsrvx',
#  'dear voucher holder claim week offer pc plea go http//www.etlp.co.uk/expressoff tsc apply. stop text txt stop 80062',
#  'thank much. skype wit kz sura didnt get pleasur company. hope good. weve given ultimatum oh countin aburo. enjoy messag sent day ago',
#  'sure result offer',
#  'good morn dear........... great amp success day.',
#  'want 750 anytim network min 150 text new video phone five pound per week call 08002888812 repli deliveri tomorrow',
#  'sir late pay rent past month pay ltgt charge. felt would inconsider nag someth give great cost that didnt speak up. howev recess wont abl pay charg month henc askin well ahead month end. plea help. thank',
#  'tri contact offer new video phone 750 anytim network min half price rental camcord call 08000930705 repli deliveri wed',
#  'last chanc 2 claim ur å150 worth discount voucherstext ye 85023 nowsavamobmemb offer mobil c 08717898035. å3.00 sub. 16 . remov txt x stop',
#  'luv u soo much u donåõt understand special u r 2 ring u 2morrow luv u xxx',
#  'pl send comprehens mail im pay much.',
#  'prashanthettan mother pas away last night. pray family.',
#  'urgent call 09066350750 landline. complimentari 4 ibiza holiday 10000 cash await collect sae tc po box 434 sk3 8wp 150 ppm 18',
#  'k.kwhen go',
#  'meanwhil shit suit xavier decid give u ltgt second warn samantha come play jay guitar impress shit. also dont think doug realiz dont live anymor',
#  'stomach thru much trauma swear cant eat. better lose weight.',
#  'officewhat matter..msg now.i call break.',
#  'yeah there bare enough room two u x mani fuck shoes. sorri man see later',
#  'today offer claim ur å150 worth discount voucher text ye 85023 savamob member offer mobil c 08717898035. å3.00 sub. 16 . unsub repli x',
#  'u reach orchard alreadi u wan 2 go buy ticket first',
#  'real babi want bring inner tigress...',
#  'da run activ full version da.',
#  'ah poor babyhop urfeel bettersn luv probthat overdos work hey go care spk 2 u sn lot lovejen xxx.',
#  'stop story. ive told ive return he say order it.',
#  'talk sexi make new friend fall love world discreet text date service. text vip 83110 see could meet.',
#  'go take babe',
#  'hai ana tomarrow come morning. ltdecimalgt ill sathi go rto office. repli came home.',
#  'spoon okay',
#  'say somebodi name tampa',
#  'work now. go min.',
#  'brother geniu',
#  'sorri guess whenev get hold connect mayb hour two ill text',
#  'u find time bu coz need sort stuff out.',
#  'dude ive see lotta corvett late',
#  'congratul ur award either yr suppli cd virgin record mysteri gift guarante call 09061104283 tsc www.smsco.net å1.50pm approx 3min',
#  'consid wall bunker shit import never play peac guess place high enough dont matter',
#  'privat 2003 account statement 07808 xxxxxx show 800 unredeem s. i. m. points. call 08719899217 identifi code 41685 expir 07/11/04',
#  'hello. need posh bird chap user trial prod champneys. put need address dob asap. ta r',
#  'u want xma 100 free text messag new video phone half price line rental call free 0800 0721072 find',
#  'well offici philosoph hole u wanna call home readi save',
#  'go good...no problem..but still need littl experi understand american custom voice...',
#  'ill text drop x',
#  'ugh long day. im exhausted. want cuddl take nap',
#  'talk atleast day... otherwis miss best friend world... shakespear shesil ltgt',
#  'shop till u drop either 10k 5k å500 cash å100 travel voucher call 09064011000. ntt po box cr01327bt fixedlin cost 150ppm mobil vari',
#  'castor need see someth',
#  'sunshin quiz wkli q win top soni dvd player u know countri liverpool play mid week txt ansr 82277. å1.50 sptyron',
#  'u secret admir look 2 make contact ufind rreveal think ur specialcal 09058094565',
#  'u secret admir look 2 make contact ufind rreveal think ur specialcal 09065171142stopsms08',
#  'remind download content alreadi paid for. goto http//doit. mymoby. tv/ collect content.',
#  'see knew give break time woul lead alway want miss curfew. gonna gibe til one midnight movi gonna get til 2. need come home. need getsleep anyth need b studdi ear training.',
#  'love give massages. use lot babi oil... fave posit',
#  'dude go sup',
#  'yoyyooo u know chang permiss drive mac. usb flash drive',
#  'gibb unsold.mik hussey',
#  'like talk pa abl to. dont know y.',
#  'dun cut short leh. u dun like ah failed. she quit sad.',
#  'unbeliev faglord',
#  'wife.how knew time murder exactli',
#  'ask princess',
#  'great princess think',
#  'nutter. cutter. ctter. cttergg. cttargg. ctargg. ctagg. ie',
#  'ok noe ure busi im realli bore msg u. oso dunno wat colour choos 4 one.',
#  'doesnt g class earli tomorrow thu shouldnt tri smoke ltgt',
#  'superb thought grate u dont everyth u want. mean u still opportun happier tomorrow u today.',
#  'hope good week. check',
#  'im use it. hope agent dont drop sinc ive book thing year. whole boston nyc experiment.',
#  'thursday night yeah sure thing well work',
#  'free rington wait collected. simpli text password mix 85069 verify. get usher britney. fml',
#  'probabl money worries. thing come due sever outstand invoic work two three month ago.',
#  'possibl teach you. where.',
#  'wonder phone batteri went dead tell love babe',
#  'love smell bu aint tobacco...',
#  'get worri derek taylor alreadi assum worst',
#  'hey what charl sorri late reply.',
#  'lastest stereophon marley dizze racal libertin stroke win nookii game flirt click themob wap bookmark text wap 82468',
#  'i.ll give it. plu said grinul greet whenev speak',
#  'white fudg oreo store',
#  'januari male sale hot gay chat cheaper call 08709222922. nation rate 1.5p/min cheap 7.8p/min peak stop text call 08712460324 10p/min',
#  'love come took long leav zaher got word ym happi see sad left. miss',
#  'sorri hurt you.',
#  'cant. feel nauseous. im pissed. didnt eat sweet week caus today plan pig out. diet week. im hungri /',
#  'ok lor early. still project meet now.',
#  'call da wait call.',
#  'could ask carlo could get anybodi el chip',
#  'actual send remind today. wonder weekend',
#  'peopl see msg think iam addict msging... wrong bcoz dont know iam addict sweet friends.. bslvyl',
#  'hey gave photo regist drive ah tmr wanna meet yck',
#  'dont talk ever ok word.',
#  'u wana see',
#  'way school. pl send ashley number',
#  'shall fine. avalarr now. hollalat',
#  'went attend anoth two round today..but still didt reach home..',
#  'actual delet old website..now blog magicalsongs.blogspot.com',
#  'k wait chikku..il send aftr ltgt min',
#  'im diet. ate 1 mani slice pizza yesterday. ugh im alway diet.',
#  'ki give kvb acc detail',
#  'oh come ah',
#  'money r lucki winner 2 claim prize text money 2 88600 å1million give away ppt150x3normal text rate box403 w1t1ji',
#  'im realli sorri wont b abl 2 friday.hop u find alternative.hop yr term go ok',
#  'congratul ore mo owo wa. enjoy wish mani happi moment fro wherev go',
#  'samu shoulder yet',
#  'time think youll need know near campu',
#  'dear matthew plea call 09063440451 landlin complimentari 4lux tenerif holiday å1000 cash await collection. ppm150 sae tc box334 sk38xh.',
#  'dun wear jean lor...',
#  'sinc side fever vomitin.',
#  'kk.are colleg',
#  'urgent call 09061749602 landline. complimentari 4 tenerif holiday å10000 cash await collect sae tc box 528 hp20 1yf 150ppm 18',
#  'better. made friday stuf like pig yesterday. feel bleh. least writh pain kind bleh.',
#  'sell well ton coins. sell coin someon thru paypal. voila money back life pocket',
#  'theyr lot places. hospit medic place safe.',
#  'get touch folk wait compani txt back name age opt enjoy commun 150p/sm',
#  'also ive sorta blown coupl time recent id rather text blue look weed',
#  'sent score sopha secondari applic schools. think think appli research cost also. contact joke ogunrind school one le expens one',
#  'cant wait see photo use',
#  'ur cashbal current 500 pound maxim ur cashin send go 86688 150p/msg. cc 08718720201 po box 114/14 tcr/w1',
#  'hey book kb sat already... lesson go ah keep sat night free need meet confirm lodg',
#  'chk ur belovd m dict',
#  'time want come',
#  'awesom lemm know whenev your around',
#  'shb b ok lor... thanx...',
#  'beauti truth gravity.. read care heart feel light someon it.. feel heavi someon leav it.. good night',
#  'also rememb get dobbi bowl car',
#  'filthi stori girl wait',
#  'sorri c ur msg... yar lor poor thing... 4 one night... tmr ull brand new room 2 sleep in...',
#  'love isnt decis feeling. could decid love life would much simpler le magic',
#  'welp appar retir',
#  'sort code acc . bank natwest. repli confirm ive sent right person',
#  '',
#  'u sure u cant take sick time',
#  'urgent tri contact u. today draw show å800 prize guaranteed. call 09050001808 land line. claim m95. valid12hr',
#  'watch cartoon listen music amp eve go templ amp church.. u',
#  'yo chad gymnast class wanna take site say christian class full..',
#  'much buzi',
#  'better still catch let ask sell ltgt me.',
#  'sure night menu. . . know noon menu',
#  'u want come back.a beauti necklac token heart you.that give wife liking.b see..no one give that.dont call me.i wait till come.',
#  'will go aptitud class.',
#  'wont b 2.15 tri 2 sort hous ok',
#  'yar lor wan 2 go c hors race today mah eat earlier lor. ate chicken rice. u',
#  'haha awesom omw back',
#  'yup thk e shop close lor.',
#  'account number',
#  'eh u send wrongli lar...',
#  'hey ad crap nite borin without ya 2 boggi u bore biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesitate. know second time weak like that. keep notebook eat day anyth chang day sure noth',
#  'hey pay. salari de. ltgt .',
#  'anoth month. need chocol weed alcohol.',
#  'start search get job days.h great potenti talent.',
#  'reckon need town eightish walk carpark.',
#  'congrat 2 mobil 3g videophon r yours. call 09063458130 videochat wid mate play java game dload polyph music nolin rentl.',
#  'look fuckin time. fuck think',
#  'yo guess drop',
#  'carlo say hell mu ltgt minut',
#  'im offic . call ltgt min',
#  'geeee ... miss alreadi know think about. fuck cant wait till next year togeth ... love kiss',
#  'yun ah.th ubi one say ì_ wan call tomorrow.cal 67441233 look irene.er got bus822656166382. ubi cresubi tech park.6ph 1st 5wkg days.ìỳn',
#  'ugh. gotta drive back sd la. butt sore.',
#  '26th juli',
#  'hi im relax time ever get 7am everi day parti good night get home tomorrow 5ish.',
#  'ì_... ìï wan come come lor... din c stripe skirt...',
#  'xma stori peace.. xma msg love.. xma miracl jesus.. hav bless month ahead amp wish u merri xmas...',
#  'cant dont number',
#  'chang again... e one next escalator...',
#  'yetund im class run water make ok. pl now.',
#  'lot happen here. feel quiet. beth aunt charli work lots. helen mo.',
#  'ì_ wait 4 bu stop aft ur lect lar. dun c ì_ go get car come back n pick ì_.',
#  'aight thank comin',
#  ...]

# %%
x=spam['sms']
y=spam['Label']

# %%
vectorizer=CountVectorizer()

# %%
x_vec=vectorizer.fit_transform(x)
vectorizer.vocabulary_
# Out:
# {'go': 3379,
#  'jurong': 4174,
#  'point': 5689,
#  'crazy': 2238,
#  'avail': 1278,
#  'bugi': 1697,
#  'great': 3468,
#  'world': 8067,
#  'la': 4302,
#  'buffet': 1695,
#  'cine': 1984,
#  'got': 3428,
#  'amor': 1063,
#  'wat': 7852,
#  'ok': 5285,
#  'lar': 4340,
#  'joke': 4138,
#  'wif': 7974,
#  'oni': 5316,
#  'free': 3190,
#  'entri': 2810,
#  'wkli': 8024,
#  'comp': 2097,
#  'win': 7986,
#  'fa': 2949,
#  'cup': 2287,
#  'final': 3057,
#  'tkt': 7362,
#  '21st': 411,
#  'may': 4707,
#  '2005': 402,
#  'text': 7216,
#  '87121': 790,
#  'receiv': 6032,
#  'questionstd': 5934,
#  'txt': 7537,
#  'ratetc': 5981,
#  'appli': 1150,
#  '08452810075over18': 74,
#  'dun': 2678,
#  'say': 6329,
#  'earli': 2694,
#  'hor': 3742,
#  'alreadi': 1035,
#  'nah': 5004,
#  'dont': 2600,
#  'think': 7285,
#  'goe': 3387,
#  'usf': 7670,
#  'live': 4459,
#  'around': 1196,
#  'though': 7303,
#  'freemsg': 3198,
#  'hey': 3660,
#  'darl': 2343,
#  'week': 7891,
#  'word': 8055,
#  'back': 1323,
#  'id': 3842,
#  'like': 4426,
#  'fun': 3253,
#  'still': 6904,
#  'tb': 7154,
#  'xxx': 8135,
#  'std': 6881,
#  'chg': 1934,
#  'send': 6406,
#  'å1': 8258,
#  '50': 614,
#  'rcv': 5994,
#  'even': 2862,
#  'brother': 1664,
#  'speak': 6778,
#  'me': 4714,
#  'treat': 7475,
#  'aid': 986,
#  'patent': 5495,
#  'per': 5536,
#  'request': 6125,
#  'mell': 4746,
#  'oru': 5377,
#  'minnaminungint': 4812,
#  'nurungu': 5221,
#  'vettam': 7725,
#  'set': 6436,
#  'callertun': 1771,
#  'callers': 1770,
#  'press': 5799,
#  'copi': 2179,
#  'friend': 3217,
#  'winner': 7994,
#  'valu': 7693,
#  'network': 5078,
#  'custom': 2299,
#  'select': 6393,
#  'receivea': 6034,
#  'å900': 8298,
#  'prize': 5831,
#  'reward': 6168,
#  'claim': 1991,
#  'call': 1759,
#  '09061701461': 219,
#  'code': 2047,
#  'kl341': 4263,
#  'valid': 7691,
#  '12': 317,
#  'hour': 3757,
#  'only': 5325,
#  'mobil': 4863,
#  '11': 308,
#  'month': 4895,
#  'entitl': 2808,
#  'updat': 7635,
#  'latest': 4355,
#  'colour': 2070,
#  'camera': 1784,
#  'co': 2036,
#  '08002986030': 59,
#  'im': 3869,
#  'gonna': 3404,
#  'home': 3719,
#  'soon': 6737,
#  'want': 7833,
#  'talk': 7125,
#  'stuff': 6972,
#  'anymor': 1114,
#  'tonight': 7415,
#  'ive': 4051,
#  'cri': 2249,
#  'enough': 2802,
#  'today': 7382,
#  'six': 6602,
#  'chanc': 1876,
#  'cash': 1831,
#  '100': 293,
#  '20000': 399,
#  'pound': 5744,
#  'csh11': 2268,
#  '87575': 794,
#  'cost': 2194,
#  '150p': 344,
#  'day': 2359,
#  '6day': 685,
#  '16': 356,
#  'tsandc': 7505,
#  'repli': 6117,
#  'hl': 3691,
#  'info': 3932,
#  'urgent': 7653,
#  'membership': 4751,
#  'å100000': 8263,
#  'jackpot': 4069,
#  '81010': 742,
#  'tc': 7156,
#  'www': 8115,
#  'dbuk': 2368,
#  'net': 5073,
#  'lccltd': 4367,
#  'pobox': 5668,
#  '4403ldnw1a7rw18': 564,
#  'search': 6369,
#  'right': 6180,
#  'thank': 7232,
#  'breather': 1637,
#  'promis': 5861,
#  'wont': 8046,
#  'take': 7120,
#  'help': 3637,
#  'grant': 3457,
#  'fulfil': 3249,
#  'promise': 5862,
#  'wonder': 8044,
#  'bless': 1520,
#  'times': 7343,
#  'date': 2351,
#  'sunday': 7026,
#  'xxxmobilemovieclub': 8136,
#  'use': 7666,
#  'credit': 2245,
#  'click': 2009,
#  'wap': 7835,
#  'link': 4441,
#  'next': 5093,
#  'messag': 4767,
#  'http': 3781,
#  'comnqjkgighjjgcbl': 2095,
#  'oh': 5279,
#  'watch': 7853,
#  'eh': 2742,
#  'rememb': 6096,
#  'spell': 6790,
#  'name': 5011,
#  'ye': 8161,
#  'did': 2486,
#  'naughti': 5036,
#  'make': 4637,
#  'wet': 7926,
#  'fine': 3064,
#  'thatåõ': 7247,
#  'way': 7865,
#  'feel': 3019,
#  'gota': 3429,
#  'england': 2795,
#  'macedonia': 4603,
#  'miss': 4829,
#  'goals': 3383,
#  'team': 7167,
#  'news': 5089,
#  'ur': 7649,
#  'nation': 5029,
#  '87077': 789,
#  'eg': 2736,
#  'trywal': 7504,
#  'scotland': 6351,
#  '4txt': 607,
#  'ìỳ1': 8311,
#  '20': 396,
#  'poboxox36504w45wq': 5680,
#  'serious': 6428,
#  'iûṫm': 4062,
#  'tri': 7481,
#  'ha': 3528,
#  'ì_': 8306,
#  'pay': 5505,
#  'first': 3080,
#  'da': 2315,
#  'stock': 6907,
#  'comin': 2085,
#  'aft': 956,
#  'finish': 3069,
#  'lunch': 4569,
#  'str': 6931,
#  'lor': 4505,
#  'ard': 1175,
#  'smth': 6677,
#  'ffffffffff': 3032,
#  'alright': 1037,
#  'meet': 4733,
#  'sooner': 6738,
#  'forc': 3144,
#  'eat': 2710,
#  'slice': 6633,
#  'realli': 6016,
#  'hungri': 3798,
#  'tho': 7299,
#  'sucks': 7000,
#  'mark': 4669,
#  'get': 3334,
#  'worried': 8071,
#  'know': 4270,
#  'sick': 6555,
#  'turn': 7524,
#  'pizza': 5626,
#  'lol': 4487,
#  'alway': 1046,
#  'convincing': 2167,
#  'catch': 1840,
#  'bu': 1685,
#  'fri': 3214,
#  'egg': 2738,
#  'tea': 7163,
#  'mom': 4882,
#  'left': 4384,
#  'dinner': 2516,
#  'love': 4526,
#  'amp': 1065,
#  'pack': 5432,
#  'car': 1809,
#  'ill': 3867,
#  'let': 4402,
#  'there': 7268,
#  'room': 6220,
#  'ahhh': 980,
#  'work': 8059,
#  'vagu': 7686,
#  'wait': 7810,
#  'that': 7242,
#  'clear': 2004,
#  'sure': 7050,
#  'sarcast': 6310,
#  'doesnt': 2574,
#  'yeah': 8162,
#  'apologetic': 1138,
#  'fallen': 2972,
#  'actin': 905,
#  'spoilt': 6816,
#  'child': 1943,
#  'caught': 1842,
#  'till': 7339,
#  'badli': 1328,
#  'cheers': 1917,
#  'tell': 7184,
#  'anyth': 1119,
#  'you': 8204,
#  'fear': 3009,
#  'faint': 2963,
#  'housework': 3764,
#  'quick': 5935,
#  'cuppa': 2289,
#  'subscript': 6988,
#  'rington': 6187,
#  'uk': 7566,
#  'charg': 1887,
#  'å5': 8284,
#  'plea': 5645,
#  'confirm': 2134,
#  'no': 5128,
#  'yup': 8242,
#  'look': 4498,
#  'time': 7341,
#  'msg': 4934,
#  'again': 963,
#  'xuhui': 8131,
#  'learn': 4377,
#  '2nd': 462,
#  'lesson': 4400,
#  '8am': 816,
#  'oop': 5337,
#  'roommat': 6222,
#  'done': 2598,
#  'see': 6383,
#  'letter': 4403,
#  'decide': 2392,
#  'hello': 3633,
#  'how': 3765,
#  'saturday': 6322,
#  'youd': 8207,
#  'decid': 2391,
#  'tomo': 7402,
#  'invit': 3994,
#  'pl': 5627,
#  'ahead': 979,
#  'watts': 7862,
#  'weekend': 7893,
#  'abiola': 862,
#  'forget': 3152,
#  'need': 5056,
#  'crave': 2235,
#  'sweet': 7078,
#  'arabian': 1171,
#  'steed': 6887,
#  'mmmmmm': 4853,
#  'yummi': 8235,
#  '07732584351': 28,
#  'rodger': 6211,
#  'burn': 1712,
#  'sm': 6650,
#  'nokia': 5146,
#  'camcorder': 1782,
#  '08000930705': 55,
#  'deliveri': 2422,
#  'tomorrow': 7405,
#  'hope': 3738,
#  'man': 4645,
#  'well': 7906,
#  'endowed': 2785,
#  'ltgt': 4554,
#  'inches': 3902,
#  'calls': 1776,
#  'messages': 4769,
#  'didnt': 2488,
#  'hep': 3649,
#  'immunis': 3882,
#  'nigeria': 5104,
#  'fair': 2964,
#  'tyler': 7551,
#  'cant': 1799,
#  'could': 2203,
#  'mayb': 4708,
#  'ask': 1220,
#  'bit': 1503,
#  'stubborn': 6960,
#  'am': 1048,
#  'hospital': 3749,
#  'kept': 4224,
#  'weak': 7871,
#  'sucker': 6998,
#  'hospit': 3748,
#  'suckers': 6999,
#  'saw': 6328,
#  'class': 1998,
#  'gram': 3450,
#  'usual': 7675,
#  'run': 6254,
#  'half': 3544,
#  'eighth': 2745,
#  'smarter': 6656,
#  'almost': 1030,
#  'whole': 7963,
#  'second': 6373,
#  'fyi': 3268,
#  'ride': 6179,
#  'morn': 4905,
#  'he': 3601,
#  'crash': 2234,
#  'place': 5628,
#  'wow': 8088,
#  'never': 5080,
#  'realiz': 6015,
#  'embarass': 2768,
#  'accomodations': 890,
#  'thought': 7304,
#  'sinc': 6578,
#  'best': 1458,
#  'seem': 6387,
#  'happi': 3568,
#  'cave': 1844,
#  'sorri': 6745,
#  'give': 3361,
#  'offered': 5263,
#  'embarassing': 2769,
#  'sms': 6670,
#  'ac': 877,
#  'sptv': 6836,
#  'new': 5084,
#  'jersey': 4113,
#  'devil': 2466,
#  'detroit': 2462,
#  'red': 6051,
#  'wing': 7993,
#  'play': 5640,
#  'ice': 3836,
#  'hockey': 3705,
#  'correct': 2186,
#  'incorrect': 3911,
#  'end': 2782,
#  'mallika': 4644,
#  'sherawat': 6485,
#  'yesterday': 8186,
#  'find': 3063,
#  'lturlgt': 4557,
#  'congrat': 2140,
#  'year': 8164,
#  'special': 6779,
#  'cinema': 1985,
#  'pas': 5485,
#  'yours': 8219,
#  '09061209465': 214,
#  'suprman': 7048,
#  'matrix3': 4697,
#  'starwars3': 6873,
#  'etc': 2848,
#  'bx420ip45we': 1736,
#  '150pm': 346,
#  'later': 4353,
#  'meeting': 4736,
#  'reach': 5999,
#  'yes': 8176,
#  'gauti': 3298,
#  'sehwag': 6392,
#  'odi': 5255,
#  'series': 6426,
#  'pick': 5598,
#  'burger': 1709,
#  'move': 4921,
#  'pain': 5440,
#  'kill': 4244,
#  'good': 3406,
#  'girl': 3354,
#  'situat': 6600,
#  'seekers': 6386,
#  'part': 5476,
#  'check': 1909,
#  'iq': 4005,
#  'took': 7419,
#  'forev': 3148,
#  'come': 2078,
#  'doubl': 2615,
#  'hair': 3539,
#  'dresser': 2640,
#  'said': 6278,
#  'wun': 8114,
#  'cut': 2303,
#  'short': 6519,
#  'nice': 5098,
#  'advis': 940,
#  'follow': 3131,
#  'recent': 6035,
#  'review': 6166,
#  'mob': 4860,
#  'award': 1293,
#  'å1500': 8270,
#  'bonu': 1558,
#  '09066364589': 263,
#  'song': 6733,
#  'dedic': 2398,
#  'valuabl': 7694,
#  'frnd': 3225,
#  'rpli': 6233,
#  'complimentari': 2114,
#  'trip': 7483,
#  'eurodisinc': 2856,
#  'trav': 7470,
#  'acoentry41': 902,
#  'å1000': 8261,
#  'di': 2474,
#  '186å1': 364,
#  '50morefrmmob': 620,
#  'shracomorsglsuplt10': 6541,
#  'ls1': 4544,
#  '3aj': 519,
#  'hear': 3612,
#  'divorc': 2553,
#  'barbi': 1356,
#  'ken': 4221,
#  'plane': 5633,
#  'wah': 7803,
#  'lucki': 4561,
#  'save': 6326,
#  'money': 4888,
#  'hee': 3626,
#  'hi': 3665,
#  'babe': 1314,
#  'wanna': 7831,
#  'someth': 6718,
#  'xx': 8132,
#  'kwhere': 4294,
#  'youhow': 8209,
#  'perform': 5541,
#  'now': 5190,
#  'machan': 4605,
#  'cool': 2173,
#  'gentleman': 3325,
#  'digniti': 2507,
#  'respect': 6141,
#  'peopl': 5534,
#  'much': 4956,
#  'shi': 6488,
#  'pa': 5430,
#  'oper': 5341,
#  'here': 3651,
#  'job': 4129,
#  'ta': 7104,
#  'earn': 2699,
#  'ah': 977,
#  'stop': 6916,
#  'urgnt': 7656,
#  'real': 6010,
#  'yo': 8198,
#  'ticket': 7328,
#  'one': 5312,
#  'jacket': 4068,
#  'multis': 4966,
#  'start': 6868,
#  'came': 1783,
#  'bed': 1416,
#  'coin': 2052,
#  'factori': 2956,
#  'too': 7418,
#  'gotta': 3434,
#  'nitros': 5123,
#  'ela': 2750,
#  'kano': 4201,
#  'il': 3865,
#  'download': 2623,
#  'wen': 7910,
#  'donûṫt': 2606,
#  'stand': 6860,
#  'close': 2014,
#  'youûṫll': 8228,
#  'anoth': 1098,
#  'night': 5106,
#  'spent': 6793,
#  'late': 4349,
#  'afternoon': 959,
#  'casualti': 1838,
#  'mean': 4716,
#  'havent': 3594,
#  'stuff42moro': 6973,
#  'includ': 3906,
#  'sheet': 6479,
#  'sorry': 6748,
#  'smile': 6662,
#  'pleasur': 5650,
#  'troubl': 7488,
#  'pour': 5745,
#  'rain': 5955,
#  'sum1': 7017,
#  'hurt': 3809,
#  'becoz': 1414,
#  'someon': 6712,
#  'servic': 6432,
#  'repres': 6123,
#  '0800': 51,
#  '169': 358,
#  '6031': 654,
#  '10am9pm': 303,
#  'guarante': 3500,
#  'å5000': 8287,
#  'plan': 5632,
#  'buy': 1726,
#  'lido': 4412,
#  '530': 632,
#  'show': 6536,
#  'collected': 2063,
#  'simpli': 6575,
#  'password': 5491,
#  'mix': 4844,
#  '85069': 775,
#  'verify': 7722,
#  'usher': 7671,
#  'britney': 1655,
#  'fml': 3125,
#  'telugu': 7188,
#  'movie': 4923,
#  'abt': 873,
#  'load': 4471,
#  'loan': 4472,
#  'wk': 8020,
#  'hol': 3709,
#  'forgot': 3155,
#  'hairdress': 3541,
#  'appoint': 1153,
#  'four': 3172,
#  'shower': 6537,
#  'beforehand': 1429,
#  'caus': 1843,
#  'prob': 5835,
#  'ham': 3550,
#  'anymore': 1115,
#  'noth': 5176,
#  'el': 2749,
#  'okay': 5286,
#  'price': 5813,
#  'long': 4494,
#  'legal': 4387,
#  'ave': 1284,
#  'gone': 3401,
#  '4the': 605,
#  'drive': 2645,
#  'test': 7211,
#  'yet': 8187,
#  'your': 8216,
#  'guess': 3508,
#  'gave': 3299,
#  'boston': 1578,
#  'men': 4754,
#  'chang': 1878,
#  'locat': 4475,
#  'nyc': 5232,
#  'changed': 1880,
#  'cuz': 2309,
#  'signin': 6563,
#  'page': 5436,
#  'umma': 7574,
#  'life': 4415,
#  'vava': 7708,
#  'lot': 4512,
#  'dear': 2375,
#  'wish': 8004,
#  'birthday': 1501,
#  'truli': 7496,
#  'memorable': 4752,
#  'aight': 988,
#  'hit': 3685,
#  'would': 8084,
#  'ip': 3999,
#  'address': 917,
#  'consid': 2148,
#  'comput': 2118,
#  'isnt': 4021,
#  'minecraft': 4806,
#  'server': 6431,
#  'grumpi': 3494,
#  'old': 5300,
#  'people': 5535,
#  'better': 1467,
#  'lying': 4584,
#  'jokes': 4140,
#  'worry': 8074,
#  'busy': 1721,
#  'plural': 5661,
#  'noun': 5187,
#  'research': 6129,
#  'after': 957,
#  'things': 7284,
#  'scare': 6337,
#  'mah': 4627,
#  'loud': 4520,
#  'gent': 3322,
#  'contact': 2154,
#  'last': 4347,
#  'draw': 2634,
#  'guaranteed': 3501,
#  '09064012160': 238,
#  'k52': 4181,
#  '12hr': 328,
#  '150ppm': 348,
#  'wa': 7798,
#  'openin': 5340,
#  'sentenc': 6418,
#  'formal': 3159,
#  'anyway': 1126,
#  'juz': 4180,
#  'tt': 7512,
#  'eatin': 2712,
#  'puttin': 5915,
#  'weight': 7897,
#  'haha': 3535,
#  'anythin': 1121,
#  'happen': 3564,
#  'enter': 2804,
#  'cabin': 1746,
#  'bday': 1402,
#  'bos': 1577,
#  'felt': 3024,
#  'askd': 1221,
#  'apartment': 1131,
#  'went': 7913,
#  'holiday': 3715,
#  'flight': 3105,
#  'inc': 3900,
#  '0871277810910p': 122,
#  'min': 4799,
#  '18': 361,
#  'goodo': 3418,
#  'must': 4980,
#  'friday': 3215,
#  'eggpotato': 2739,
#  'ratio': 5983,
#  'tortilla': 7434,
#  'hmm': 3696,
#  'mi': 4782,
#  'uncl': 7582,
#  'inform': 3934,
#  'school': 6343,
#  'directly': 2523,
#  'food': 3136,
#  'privat': 5828,
#  '2004': 401,
#  'account': 893,
#  'statement': 6876,
#  '07742676969': 30,
#  '786': 714,
#  'unredeem': 7624,
#  'points': 5690,
#  '08719180248': 170,
#  'identifi': 3848,
#  '45239': 573,
#  'expir': 2927,
#  'å2000': 8274,
#  'caller': 1769,
#  '03': 14,
#  'landlin': 4327,
#  '09064019788': 244,
#  'box42wr29c': 1604,
#  'applespairsal': 1149,
#  'malarki': 4641,
#  'voda': 7767,
#  'number': 5216,
#  '7548': 707,
#  '350': 510,
#  'match': 4688,
#  '08712300220': 104,
#  'quot': 5943,
#  '4041': 549,
#  'standard': 6861,
#  'rate': 5980,
#  'app': 1141,
#  'sao': 6304,
#  'mu': 4954,
#  'ìï': 8309,
#  'predict': 5776,
#  'ì_ll': 8307,
#  'do': 2563,
#  'knowyetund': 4273,
#  'hasnt': 3584,
#  'sent': 6416,
#  'bother': 1581,
#  'sending': 6409,
#  'involv': 3997,
#  'anything': 1122,
#  'shouldnt': 6531,
#  'impos': 3890,
#  'apologise': 1140,
#  'del': 2415,
#  'bak': 1335,
#  'sum': 7016,
#  'lucyxx': 4566,
#  'khow': 4235,
#  'tmorrow': 7369,
#  'accomodate': 889,
#  'answer': 1102,
#  'question': 5932,
#  'sunshin': 7033,
#  'quiz': 5940,
#  'top': 7427,
#  'soni': 6734,
#  'dvd': 2687,
#  'player': 5641,
#  'countri': 2210,
#  'algarv': 1015,
#  'ansr': 1101,
#  '82277': 748,
#  'sptyron': 6837,
#  'laid': 4319,
#  'dog': 2577,
#  'direct': 2521,
#  'join': 4136,
#  'largest': 4344,
#  'bt': 1678,
#  'txting': 7545,
#  'gravel': 3462,
#  '69888': 680,
#  'nt': 5207,
#  'ec2a': 2715,
#  '31p': 503,
#  'msg150p': 4935,
#  'haf': 3534,
#  'msn': 4946,
#  'yijuehotmail': 8195,
#  'com': 2073,
#  'befor': 1427,
#  'activ': 907,
#  'youll': 8212,
#  'chat': 1898,
#  'svc': 7063,
#  'hardcor': 3575,
#  '69988': 684,
#  'age': 966,
#  'verifi': 7721,
#  'yr': 8232,
#  'lazi': 4365,
#  'type': 7552,
#  'lect': 4382,
#  'pouch': 5743,
#  'sir': 6588,
#  'mail': 4630,
#  'swt': 7091,
#  'nver': 5226,
#  'tire': 7349,
#  'littl': 4457,
#  'thing': 7283,
#  'lovabl': 4524,
#  'persons': 5557,
#  'coz': 2222,
#  'somtim': 6730,
#  'occupi': 5249,
#  'biggest': 1486,
#  'hearts': 3617,
#  'gud': 3503,
#  'ni8': 5096,
#  'are': 1176,
#  'open': 5339,
#  'ya': 8145,
#  'dot': 2614,
#  'what': 7934,
#  'staff': 6854,
#  'randi': 5970,
#  'sexi': 6443,
#  'femal': 3025,
#  'local': 4474,
#  'luv': 4575,
#  'netcollex': 5074,
#  'ltd': 4550,
#  '08700621170150p': 76,
#  'ummma': 7576,
#  'wil': 7980,
#  'in': 3898,
#  'our': 5389,
#  'begin': 1432,
#  'qatar': 5920,
#  'pray': 5770,
#  'hard': 3574,
#  'delet': 2417,
#  'sindu': 6581,
#  'birla': 1497,
#  'soft': 6700,
#  'wine': 7992,
#  'flow': 3116,
#  'nevering': 5081,
#  'thk': 7293,
#  'plaza': 5644,
#  'typic': 7553,
#  'reply': 6118,
#  'everywher': 2879,
#  'dirt': 2526,
#  'floor': 3113,
#  'window': 7990,
#  'shirt': 6498,
#  'sometim': 6721,
#  'mouth': 4920,
#  'out': 5392,
#  'dream': 2636,
#  'without': 8014,
#  'chore': 1970,
#  'joy': 4154,
#  'tv': 7526,
#  'll': 4465,
#  'exist': 2913,
#  'hail': 3538,
#  'mist': 4836,
#  'becom': 1413,
#  'aaooooright': 852,
#  'leav': 4380,
#  'hous': 3760,
#  'interview': 3982,
#  'boy': 1609,
#  'mear': 4721,
#  'annoncement': 1091,
#  '07046744435': 22,
#  'arrang': 1199,
#  '0871277810810': 121,
#  'keep': 4218,
#  'safe': 6274,
#  'envi': 2816,
#  'everyon': 2872,
#  'parents': 5470,
#  'hand': 3553,
#  'excit': 2903,
#  'spend': 6792,
#  'happy': 3573,
#  'bootydeli': 1569,
#  '32': 504,
#  'yes434': 8178,
#  'no434': 5131,
#  '62468': 661,
#  'bangbab': 1350,
#  'order': 5365,
#  'content': 2156,
#  'goto': 3433,
#  'bangb': 1349,
#  'internet': 3981,
#  'menu': 4759,
#  'cultur': 2284,
#  'modul': 4876,
#  'already': 1036,
#  '09061701939': 221,
#  's89': 6264,
#  'avoid': 1290,
#  'missunderstd': 4835,
#  'wit': 8009,
#  'belov': 1446,
#  'escape': 2836,
#  'fanci': 2980,
#  'bridg': 1642,
#  'lager': 4318,
#  'complet': 2109,
#  'formclark': 3163,
#  'also': 1040,
#  'utter': 7677,
#  'waste': 7849,
#  'axi': 1300,
#  'bank': 1351,
#  'hmmm': 3697,
#  'hop': 3737,
#  'muz': 4986,
#  'discus': 2539,
#  'liao': 4407,
#  'bloodi': 1531,
#  'hell': 3631,
#  'believ': 1438,
#  'surnam': 7054,
#  'mr': 4928,
#  'clue': 2028,
#  'spanish': 6773,
#  'bath': 1374,
#  'fin': 3056,
#  'youv': 8224,
#  'carlo': 1820,
#  'mall': 4643,
#  'stay': 6879,
#  'til': 7338,
#  'smoke': 6667,
#  'worth': 8078,
#  'her': 3650,
#  'log': 4479,
#  'spoke': 6817,
#  'maneesha': 4653,
#  'wed': 7884,
#  'satisfi': 6319,
#  'experience': 2923,
#  'toll': 7398,
#  'lift': 4421,
#  'offer': 5262,
#  'especi': 2839,
#  'approach': 1157,
#  'studying': 6969,
#  'gr8': 3442,
#  'trust': 7499,
#  'guy': 3520,
#  'by': 1738,
#  'handsom': 3557,
#  'toward': 7447,
#  'mummi': 4970,
#  'where': 7947,
#  'boytoy': 1615,
#  'awesom': 1295,
#  'minut': 4818,
#  'freephon': 3202,
#  '0808': 63,
#  '145': 338,
#  '4742': 577,
#  '9am11pm': 840,
#  'xma': 8126,
#  'radio': 5949,
#  'ju': 4160,
#  'si': 6551,
#  'uniqu': 7610,
#  '30th': 499,
#  ...}

# %%
(x_train,x_test,y_train,y_test)=train_test_split(x_vec,y)

# %%
x_train
# Out:
# <4179x8319 sparse matrix of type '<class 'numpy.int64'>'
# 	with 36695 stored elements in Compressed Sparse Row format>

# %%
# Used Voting Class Classier

clf_1=KNeighborsClassifier(n_neighbors=3,metric='euclidean')
clf_2=GaussianNB()
clf_3=SVC(C=100,kernel='rbf')
clf_4=RandomForestClassifier(n_estimators=50,random_state=1)

vc=VotingClassifier(estimators=[('knn',clf_1),('nb',clf_2),('svm',clf_3),('rfc',clf_4)],voting='hard') 
vc.fit(x_train.toarray(),y_train)
# Out:
# VotingClassifier(estimators=[('knn',
#                               KNeighborsClassifier(metric='euclidean',
#                                                    n_neighbors=3)),
#                              ('nb', GaussianNB()), ('svm', SVC(C=100)),
#                              ('rfc',
#                               RandomForestClassifier(n_estimators=50,
#                                                      random_state=1))])

# %%
vc.score(x_test.toarray(),y_test)
# Out:
# 0.9741564967695621

# %%
vc.score(x_train.toarray(),y_train)
# Out:
# 1.0

# %%
# used SVM model to predict and methods like RandomSearchCV and GridSearchCV to find best suited hyperparameters
clf=SVC()
para = {'C':[10,10,0.1,0.01,1000],'kernel':['rbf','linear','poly']}

# %%
random=RandomizedSearchCV(clf,param_distributions=para,cv=5)

# %%
random.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [10, 10, 0.1, 0.01, 1000],
#                                         'kernel': ['rbf', 'linear', 'poly']})

# %%
random.best_params_
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
random.best_score_
# Out:
# 0.9808549408360312

# %%
grid_search=GridSearchCV(clf,param_grid=para,cv=5)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [10, 10, 0.1, 0.01, 1000],
#                          'kernel': ['rbf', 'linear', 'poly']})

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
grid_search.best_score_
# Out:
# 0.9808549408360312
